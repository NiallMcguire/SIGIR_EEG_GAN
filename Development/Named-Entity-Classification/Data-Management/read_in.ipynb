# %%
import pickle

# %%
with open(r'C:\Users\gxb18167\PycharmProjects\SIGIR_EEG_GAN\Development\Named-Entity-Classification\Data-Management\train_NER.pkl', 'rb') as f:
    data = pickle.load(f)
    data1 = pickle.load(f)
    data2 = pickle.load(f)
# Out:
# C:\Users\gxb18167\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\gxb18167\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\gxb18167\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data
# Out:
# [['Henry', 'Ford'],
#  ['Harry', 'Bennett'],
#  ['Edsel'],
#  ['Eleanor'],
#  ['Henry', 'Ford', 'II'],
#  ['Aldous', 'Leonard', 'Huxley'],
#  ['United', 'States'],
#  ['Huxley', 'family'],
#  ['Huxley'],
#  ['Godalming'],
#  ['Surrey'],
#  ['England'],
#  ['Leonard', 'Huxley'],
#  ['Julia', 'Arnold'],
#  ['Thomas', 'Henry', 'Huxley'],
#  ['Darwin'],
#  ['Julian', 'Huxley'],
#  ['John', 'Wells'],
#  ['Wells'],
#  ['David', 'Frost'],
#  ['Millicent', 'Martin'],
#  ['BBC'],
#  ['Nancy', 'Cartwright'],
#  ['Homer'],
#  ['Marge', 'Simpson'],
#  ['Lisa'],
#  ['Maggie'],
#  ['Roy', 'Stanley', 'Geiger'],
#  ['United', 'States', 'Marine', 'Corps'],
#  ['Marine'],
#  ['Geiger'],
#  ['Middleburg'],
#  ['Florida'],
#  ['Florida', 'State', 'Normal', 'and', 'Industrial', 'College', 'and'],
#  ['Stetson', 'University'],
#  ['Marine', 'Corps'],
#  ['School'],
#  ['Port', 'Royal'],
#  ['South', 'Carolina'],
#  ['Detroit'],
#  ['III', 'Amphibious', 'Corps'],
#  ['Okinawa'],
#  ['General'],
# ...

# %%
data1[0]
# Out:
# [[array([[0.62480968, 0.86678177, 0.43499947, 0.55484807, 1.10744226,
#           0.79004747, 0.72866803, 1.2451129 ],
#          [1.2950722 , 1.39696658, 0.74467444, 0.93522722, 0.8823545 ,
#           1.31491029, 1.27846992, 1.0310688 ],
#          [0.76308107, 1.0802604 , 1.22258008, 0.6715678 , 1.09085226,
#           0.98258072, 1.4951793 , 0.78037769],
#          [0.50566727, 0.92813218, 0.89768887, 0.76817262, 0.65575385,
#           0.56499535, 0.42158231, 0.81031477],
#          [0.91529906, 0.845864  , 0.69083071, 0.40758044, 1.2672714 ,
#           0.86016208, 0.81446189, 0.72452074],
#          [0.90478975, 0.84593201, 0.81406128, 0.67327887, 0.91134506,
#           0.41202712, 0.89306521, 1.0972259 ],
#          [0.97350454, 0.99714583, 0.93347251, 1.0913049 , 1.7349664 ,
#           1.10655749, 0.98172843, 1.12126744],
#          [0.85711527, 0.9839921 , 0.94466829, 1.07521129, 0.93494856,
#           0.81240606, 0.76570928, 0.84138274],
# ...

# %%
data2[0]
# Out:
# ['B-PER', 'I-PER']
